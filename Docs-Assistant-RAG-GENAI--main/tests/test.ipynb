# %%
# test.ipynb (sample cells)

import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), ".."))) # ensure parent folder is in path if needed

from extraction.extractor import extract_file

# ---- Test with PNG ----
#with open("../city-wise-nafld.png", "rb") as f:
#    data = f.read()

#result = extract_file(data, "test.png")
#print("PNG Extraction Result:")
#print(result)

# ---- Test with PDF ----
with open("../Research on Non-alcoholic Fatty Liver Disease.pdf", "rb") as f:
     data = f.read()
result = extract_file(data, "example.pdf")
print(result)

# ---- Test with DOCX ----
with open("../J of Gastro and Hepatol - 2017 - Wong - Asia Pacific Working Party on Non_alcoholic Fatty Liver Disease guidelines 2017.docx", "rb") as f:
     data = f.read()
result = extract_file(data, "example.docx")
#print(result)
# Out:
# {'file_name': 'example.pdf', 'file_type': 'pdf', 'pages': [{'page_number': 1, 'text': "Review Article\nResearch on Non-alcoholic Fatty Liver Disease From\nIndian Subcontinent: A Bibliometric Analysis of\nPublications During 2001–2022\nRajuVaishya*,BrijM.Gupta y ,MallikarjunM.Kappi z ,AnoopMisra x,k,{ ,MohammadS.Kuchay#,AbhishekVaish*\n*DepartmentofOrthopaedicsandJointReplacementSurgery,IndraprasthaApolloHospitals,SaritaVihar,NewDelhi,110076,India,yFormerly\nwithCSIR-NISTADS,NewDelhi,110012,India,zGovernmentFirstGradeCollege,Jagalur,577528,Karnataka,India,xFortis-C-DOCCentreof\nExcellenceforDiabetes,MetabolicDiseasesandEndocrinology,NewDelhi,India,kNationalDiabetes,ObesityandCholesterolFoundation(N-\nDOC),SDA,NewDelhi,India,{DiabetesFoundation,Indiaand#DivisionofEndocrinology&Diabetes,Medanta-TheMedicity,Gurugram,India\nIntroduction:Thenon-alcoholicfattyliverdisease(NAFLD)iscommonintheIndianSubcontinent.Weaimedto\nexaminethebibliometriccharacteristicsofthepublicationsarisingfromthecou
# ...

# %%
import sys, os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), ".."))) # ensure parent folder is in path if needed

from extraction.extractor import extract_file

# ---- Test with PNG ----
with open("../city-wise-nafld.png", "rb") as f:
    data = f.read()

result = extract_file(data, "test.png")
print("PNG Extraction Result:")
print(result)
# Out:
# PNG Extraction Result:
# ...
